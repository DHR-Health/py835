# %%
import pandas as pd

class CustomDataFrame(pd.DataFrame):
    @property
    def _constructor(self):
        return CustomDataFrame

    def custom_method(self):
        # Your custom processing logic here
        return self.describe()  # Example: return the DataFrame description

# Create an instance of CustomDataFrame
df = CustomDataFrame([{'a': 1, 'b': 2}, {'a': 3, 'b': 4}])

# Use the custom method
print(df.custom_method())
# Out:
#               a         b
# count  2.000000  2.000000
# mean   2.000000  3.000000
# std    1.414214  1.414214
# min    1.000000  2.000000
# 25%    1.500000  2.500000
# 50%    2.000000  3.000000
# 75%    2.500000  3.500000
# max    3.000000  4.000000

# %%
# Out:
# id-name                                                                                                                                     SERVICE AMT01-B6Amount Qualifier Code  \
# header_id                   functional_group_id         statement_id                claim_id                    service_id
# tZU0br-Xiub3d-s0gMtZ-nVyP6s dg26zp-XAp5ny-ZdOFB3-uuJp6Z Cy4TOj-VmD2mM-0v2WTx-jqZr1i 0F2Tbv-selowp-lLDnWS-U9XbGY xT0H1m-F6FEZs-XM2CBP-J7QXqM                                    B6
#                                                                                     1SNux0-v4yylX-wkIs2C-bf7Kb6 URmsrj-WNzsSU-pq5hSg-jZa3Cv                                    B6
#                                                                                                                 eiVvgt-0Bp13l-X2UmqK-dNSPE2                                   NaN
# ...
