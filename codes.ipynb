# %% [markdown]
# # 835 Field Codes
# Work in progress

# %%
from py835 import codes 

codes.get_PLB03_codes()
# Out:
#     field value                                        description
# 0   PLB03    01                        Card interchange fee amount
# 1   PLB03    02  Advanced or accelerated payment recoupment amount
# 2   PLB03    03                      Claim transmission fee amount
# 3   PLB03    04  Real-time adjudication resulting in a payment ...
# 4   PLB03    05  Penalty amount withheld due to reports that we...
# 5   PLB03    06  Penalty amount withheld due to reports that we...
# 6   PLB03    07  Non-Internal Revenue Service third-party  with...
# 7   PLB03    08     Penalty Withholding for Bankruptcy/Termination
# 8   PLB03    50  The amount of the late charge, late claim fili...
# 9   PLB03    51     Late filing interest penalty assessment amount
# 10  PLB03    72  Provider refund amountThis adjustment acknowle...
# 11  PLB03    90                     Early payment allowance amount
# 12  PLB03    AH  Claim transmission fee amountThis code is used...
# ...

# %%
from py835 import codes 

codes.get_cas01_codes()
# Out:
# 0    Missing/Invalid submitter identifier
# Name: description, dtype: object
